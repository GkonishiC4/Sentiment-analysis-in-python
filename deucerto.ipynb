# %%
import  tweepy
import pandas as pd

# %%
bearer_token ='AAAAAAAAAAAAAAAAAAAAAPX6egEAAAAApwldbV5Dtz2Qk%2F1I7CBLAEtBoP8%3DDbwEDtAm7kdkdFslmpZpqq8zSP6WAjfsN3gPwvlURvWAjTz21M' 
consumer_key ='BHprOcd8SQ5XnI60LAMxW47Ec'
consumer_secret ='2ZZcqbYv0oj4Dst9j4w6DJWTtv03kB6bvWeDuz9WqcD61rcei4' 
access_token ='3154080171-houp6OPARod8yGvdjTxbL1CczRU4dlwKelbamGi'
access_token_secret ='pSc6KsJBLvtRaesQfzCXDNKwFjrg5fg6ohB6kKuc5pnFE'
User_id='128372940'

# %%
client = tweepy.Client(bearer_token=bearer_token)

# %%
tweets=client.get_users_tweets(id=User_id,max_results=100)
tweet = tweets.data

for user in tweet:
    print(user.text)
# Out:
# - Graças a essas medidas, bem como aquelas implementadas ainda em 2019, como a lei da liberdade econômica, o Brasil está se recuperando rapidamente. Mesmo num cenário de pandemia e guerra, o desemprego ficou abaixo de 2 dígitos pela 1a vez após a recessão causada pelo PT em 2015.
# - Ciente de que o desemprego traria ainda mais sofrimento ao povo, a esquerda pediu para ignorarmos a economia, o que não aconteceu. Além de repassar recursos e disponibilizar vacina a quem desejasse, criamos o Auxílio Emergencial, o Pronampe e o BEm, que reduziram os impactos.
# - Após pregarem o "fica em casa que a economia vê depois", muitos agora alegam que nunca existiu lockdown no Brasil, como se não houvesse vários registros de trabalhadores sendo caçados como se fossem marginais e de homens e mulheres sendo detidos na rua. Viraram "negacionistas".
# ...

# %%
tweet_list = [[user.text]for user in tweet]
df = pd.DataFrame(tweet_list,columns=['Texto'])
pd.options.display.max_colwidth = 200

# %%
df.to_csv("dbBolsonaro.csv")

# %%
df.to_parquet("dbBolsonaro.parquet")

# %%
access_key = 'AKIA2LNCUZJ7UES5YIOZ'
secret_access_key ='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'

# %%
import boto3
import os 

client = boto3.client('s3',
                        aws_access_key_id = access_key,
                        aws_secret_access_key = secret_access_key)

for file in os.listdir():
    if'.parquet' in file:
        upload_file_bucket = 'execsemana9'
        upload_file_key = 'python/' + str(file)
        client.upload_file(file,upload_file_bucket,upload_file_key)
